# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import random

# %%
GRID_SIZE = 100
EMPTY_HOUSE_RATIO = 0.1
BLUE_PARTY_RATIO = .5
RED_PARTY_RATIO = 1-BLUE_PARTY_RATIO
BLUE_EFFECTIVE_RATIO = (1-EMPTY_HOUSE_RATIO) * BLUE_PARTY_RATIO
RED_EFFECTIVE_RATIO = (1-EMPTY_HOUSE_RATIO) * RED_PARTY_RATIO
#Any ratio of bad / total neighbors above this value results in an unhappy agent
RELOCATION_THRESHOLD = 0.4
EMPTY = 0
BLUE = 1
RED = 2

# %% [markdown]
# **Visualization Function**

# %%
def visualize(grid_in, title):
    colors = ['white', 'blue', 'red']
    cmap = ListedColormap(colors)

    print("Visualizing: \n")
    plt.figure(figsize=(8, 8))
    plt.imshow(grid_in, cmap=cmap, interpolation='nearest')

    plt.title(title)
    plt.show()

    print("Done.")

# %%
flat_grid = np.random.choice(
    [EMPTY, BLUE, RED],
    size = GRID_SIZE*GRID_SIZE,
    p=[EMPTY_HOUSE_RATIO, BLUE_EFFECTIVE_RATIO, RED_EFFECTIVE_RATIO]
)

# %%
grid = flat_grid.reshape(GRID_SIZE,GRID_SIZE)
visualize(grid, "Original")
# Out:
# Visualizing:
# Done.

# %%
#identify unhappy agents and available indices
def identify(grid):
    unhappy_agents = []
    empty_spots = []
    for row in range(GRID_SIZE):
        for col in range(GRID_SIZE):
            #tally neighbors
            if grid[row][col] != EMPTY:
                total_neighbors = 0
                bad_neighbors = 0
                for neighbor_row in range(max(0, row-1), min(GRID_SIZE, row+2)):
                    for neighbor_col in range(max(0, col-1), min(GRID_SIZE, col+2)):
                        if(neighbor_row != row or neighbor_col != col):
                            if(grid[neighbor_row][neighbor_col] != grid[row][col] and grid[neighbor_row][neighbor_col] != EMPTY):
                                bad_neighbors+=1
                            if grid[neighbor_row][neighbor_col] != EMPTY:
                                total_neighbors+=1
                if(not total_neighbors or bad_neighbors / total_neighbors > RELOCATION_THRESHOLD):
                    unhappy_agents.append((row,col))
            else: 
                empty_spots.append((row,col))
    return unhappy_agents, empty_spots

def relocate(grid_in, unhappy_in, empty_in):
   for agent in unhappy_in:
       destination = random.choice(empty_in)
       destination_r, destination_c = destination
       agent_r, agent_c = agent
       grid_in[destination_r][destination_c] = grid_in[agent_r][agent_c]
       grid_in[agent_r][agent_c] = EMPTY
       empty_in.remove(destination)
       empty_in.append(agent)

continue_loop = True
count = 0
print("Starting simulation\n")
while continue_loop:
    count+=1
    unhappy, empty = identify(grid)
    if not unhappy:
        continue_loop = False
    else:
        print(f"Iteration: {count} There are {len(unhappy)} unhappy agents and {len(empty)} empty spots" + "\n")
        relocate(grid, unhappy, empty)
print(f"Simulation finished after {count} iterations" + "\n")

visualize(grid, "Final")
# Out:
# Starting simulation
#
# Iteration: 1 There are 6177 unhappy agents and 1002 empty spots
#
# Iteration: 2 There are 4581 unhappy agents and 1002 empty spots
#
# Iteration: 3 There are 3583 unhappy agents and 1002 empty spots
#
# Iteration: 4 There are 2913 unhappy agents and 1002 empty spots
#
# Iteration: 5 There are 2267 unhappy agents and 1002 empty spots
#
# Iteration: 6 There are 1846 unhappy agents and 1002 empty spots
#
# Iteration: 7 There are 1550 unhappy agents and 1002 empty spots
#
# Iteration: 8 There are 1286 unhappy agents and 1002 empty spots
#
# Iteration: 9 There are 1111 unhappy agents and 1002 empty spots
#
# Iteration: 10 There are 963 unhappy agents and 1002 empty spots
#
# Iteration: 11 There are 861 unhappy agents and 1002 empty spots
#
# Iteration: 12 There are 788 unhappy agents and 1002 empty spots
#
# Iteration: 13 There are 682 unhappy agents and 1002 empty spots
#
# Iteration: 14 There are 622 unhappy agents and 1002 empty spots
#
# Iteration: 15 There are 568 unhappy agents and 1002 empty spots
#
# Iteration: 16 There are 514 unhappy agents and 1002 empty spots
#
# Iteration: 17 There are 465 unhappy agents and 1002 empty spots
#
# Iteration: 18 There are 442 unhappy agents and 1002 empty spots
#
# Iteration: 19 There are 388 unhappy agents and 1002 empty spots
#
# Iteration: 20 There are 361 unhappy agents and 1002 empty spots
#
# Iteration: 21 There are 322 unhappy agents and 1002 empty spots
#
# Iteration: 22 There are 298 unhappy agents and 1002 empty spots
#
# Iteration: 23 There are 288 unhappy agents and 1002 empty spots
#
# Iteration: 24 There are 269 unhappy agents and 1002 empty spots
#
# Iteration: 25 There are 272 unhappy agents and 1002 empty spots
#
# Iteration: 26 There are 267 unhappy agents and 1002 empty spots
#
# Iteration: 27 There are 245 unhappy agents and 1002 empty spots
#
# Iteration: 28 There are 229 unhappy agents and 1002 empty spots
#
# Iteration: 29 There are 215 unhappy agents and 1002 empty spots
#
# Iteration: 30 There are 204 unhappy agents and 1002 empty spots
#
# Iteration: 31 There are 198 unhappy agents and 1002 empty spots
#
# Iteration: 32 There are 188 unhappy agents and 1002 empty spots
#
# Iteration: 33 There are 183 unhappy agents and 1002 empty spots
#
# Iteration: 34 There are 175 unhappy agents and 1002 empty spots
#
# Iteration: 35 There are 166 unhappy agents and 1002 empty spots
#
# Iteration: 36 There are 155 unhappy agents and 1002 empty spots
#
# Iteration: 37 There are 151 unhappy agents and 1002 empty spots
#
# Iteration: 38 There are 138 unhappy agents and 1002 empty spots
#
# Iteration: 39 There are 142 unhappy agents and 1002 empty spots
#
# Iteration: 40 There are 142 unhappy agents and 1002 empty spots
#
# Iteration: 41 There are 130 unhappy agents and 1002 empty spots
#
# Iteration: 42 There are 111 unhappy agents and 1002 empty spots
#
# Iteration: 43 There are 117 unhappy agents and 1002 empty spots
#
# Iteration: 44 There are 104 unhappy agents and 1002 empty spots
#
# Iteration: 45 There are 95 unhappy agents and 1002 empty spots
#
# Iteration: 46 There are 82 unhappy agents and 1002 empty spots
#
# Iteration: 47 There are 71 unhappy agents and 1002 empty spots
#
# Iteration: 48 There are 72 unhappy agents and 1002 empty spots
#
# Iteration: 49 There are 71 unhappy agents and 1002 empty spots
#
# Iteration: 50 There are 64 unhappy agents and 1002 empty spots
#
# Iteration: 51 There are 56 unhappy agents and 1002 empty spots
#
# Iteration: 52 There are 58 unhappy agents and 1002 empty spots
#
# Iteration: 53 There are 57 unhappy agents and 1002 empty spots
#
# Iteration: 54 There are 65 unhappy agents and 1002 empty spots
#
# Iteration: 55 There are 65 unhappy agents and 1002 empty spots
#
# Iteration: 56 There are 52 unhappy agents and 1002 empty spots
#
# Iteration: 57 There are 47 unhappy agents and 1002 empty spots
#
# Iteration: 58 There are 45 unhappy agents and 1002 empty spots
#
# Iteration: 59 There are 43 unhappy agents and 1002 empty spots
#
# Iteration: 60 There are 40 unhappy agents and 1002 empty spots
#
# Iteration: 61 There are 39 unhappy agents and 1002 empty spots
#
# Iteration: 62 There are 38 unhappy agents and 1002 empty spots
#
# Iteration: 63 There are 38 unhappy agents and 1002 empty spots
#
# Iteration: 64 There are 41 unhappy agents and 1002 empty spots
#
# Iteration: 65 There are 43 unhappy agents and 1002 empty spots
#
# Iteration: 66 There are 44 unhappy agents and 1002 empty spots
#
# Iteration: 67 There are 43 unhappy agents and 1002 empty spots
#
# Iteration: 68 There are 42 unhappy agents and 1002 empty spots
#
# Iteration: 69 There are 31 unhappy agents and 1002 empty spots
#
# Iteration: 70 There are 32 unhappy agents and 1002 empty spots
#
# Iteration: 71 There are 27 unhappy agents and 1002 empty spots
#
# Iteration: 72 There are 24 unhappy agents and 1002 empty spots
#
# Iteration: 73 There are 15 unhappy agents and 1002 empty spots
#
# Iteration: 74 There are 15 unhappy agents and 1002 empty spots
#
# Iteration: 75 There are 16 unhappy agents and 1002 empty spots
#
# Iteration: 76 There are 17 unhappy agents and 1002 empty spots
#
# Iteration: 77 There are 20 unhappy agents and 1002 empty spots
#
# Iteration: 78 There are 18 unhappy agents and 1002 empty spots
#
# Iteration: 79 There are 16 unhappy agents and 1002 empty spots
#
# Iteration: 80 There are 16 unhappy agents and 1002 empty spots
#
# Iteration: 81 There are 10 unhappy agents and 1002 empty spots
#
# Iteration: 82 There are 7 unhappy agents and 1002 empty spots
#
# Iteration: 83 There are 6 unhappy agents and 1002 empty spots
#
# Iteration: 84 There are 7 unhappy agents and 1002 empty spots
#
# Iteration: 85 There are 6 unhappy agents and 1002 empty spots
#
# Iteration: 86 There are 4 unhappy agents and 1002 empty spots
#
# Iteration: 87 There are 3 unhappy agents and 1002 empty spots
#
# Iteration: 88 There are 5 unhappy agents and 1002 empty spots
#
# Iteration: 89 There are 4 unhappy agents and 1002 empty spots
#
# Iteration: 90 There are 2 unhappy agents and 1002 empty spots
#
# Iteration: 91 There are 1 unhappy agents and 1002 empty spots
#
# Simulation finished after 92 iterations
#
# Visualizing:
# Done.
